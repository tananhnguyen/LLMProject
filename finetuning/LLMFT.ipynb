# %%
# !pip install --no-cache-dir torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (2.7.1+cu118)
# Requirement already satisfied: torchvision in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (0.22.1+cu118)
# Requirement already satisfied: torchaudio in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (2.7.1+cu118)
# Requirement already satisfied: filelock in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torch) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from triton==3.3.1->torch) (78.1.1)
# Requirement already satisfied: numpy in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tananh/anaconda3/envs/llm_subject/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)

# %%
# !pip install --no-cache-dir -q accelerate peft bitsandbytes transformers trl scipy

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig,
    HfArgumentParser, TrainingArguments, pipeline, logging
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer, SFTConfig

# %%
from datasets import load_dataset

squad_dataset = load_dataset("rajpurkar/squad_v2")
print(len(squad_dataset['train']))
# Out:
# 130319

# %%
squad_dataset = squad_dataset['train'].shuffle(seed=42).sam
squad_dataset[0]
# Out:
# {'id': '56e0f3907aa994140058e80a',
#  'title': 'Canon_law',
#  'context': 'The Roman Catholic Church canon law also includes the main five rites (groups) of churches which are in full union with the Roman Catholic Church and the Supreme Pontiff:',
#  'question': 'What term characterizes the intersection of the rites with the Roman Catholic Church?',
#  'answers': {'text': ['full union'], 'answer_start': [104]}}

# %%
def transform_conversation(example):
    context = example['context']
    question = example['question']
    user_text = f"Context: {context} Question: {question}"
    answer = example['answers']['text'][0] if example['answers']['text'] else ""

    reformatted = f"<s>[INST] {user_text} [/INST] {answer} </s>"
    return {"text" : reformatted}

# %%
transformed_dataset = squad_dataset.map(transform_conversation)

# %%
transformed_dataset[0]
# Out:
# {'id': '56e0f3907aa994140058e80a',
#  'title': 'Canon_law',
#  'context': 'The Roman Catholic Church canon law also includes the main five rites (groups) of churches which are in full union with the Roman Catholic Church and the Supreme Pontiff:',
#  'question': 'What term characterizes the intersection of the rites with the Roman Catholic Church?',
#  'answers': {'text': ['full union'], 'answer_start': [104]},
#  'text': '<s>[INST] Context: The Roman Catholic Church canon law also includes the main five rites (groups) of churches which are in full union with the Roman Catholic Church and the Supreme Pontiff: Question: What term characterizes the intersection of the rites with the Roman Catholic Church? [/INST] full union </s>'}

# %%
transformed_dataset[1]['text']
# Out:
# "<s>[INST] Context: Alexandria was the most important trade center in the whole empire during Athanasius's boyhood. Intellectually, morally, and politically—it epitomized the ethnically diverse Graeco-Roman world, even more than Rome or Constantinople, Antioch or Marseilles. Its famous catechetical school, while sacrificing none of its famous passion for orthodoxy since the days of Pantaenus, Clement of Alexandria, Origen of Alexandria, Dionysius and Theognostus, had begun to take on an almost secular character in the comprehensiveness of its interests, and had counted influential pagans among its serious auditors. Question: What was Alexandria known for? [/INST] important trade center </s>"

# %%
model_name = "NousResearch/Llama-2-7b-chat-hf"
dataset_name = "rajpurkar/squad_v2"
finetune_model = "Llama-2-7b-chat-finetune"


# Output folder
output_dir = "./results"

# No of epochs
num_train_epochs = 1

# No change params
use_4bit, bnb_4bit_compute_dtype, bnb_4bit_quant_type, use_nested_quant = True, "float16", "nf4", False # To quantization
lora_r, lora_alpha, lora_dropout = 64, 16, 0.1
fp16, bf16 =  False, False
per_device_train_batch_size, per_device_eval_batch_size = 1, 1
gradient_accumulation_steps, gradient_checkpointing, max_grad_norm = 1, True, 0.3
learning_rate, weight_decay, optim = 2e-4, 0.001, "paged_adamw_32bit"
lr_scheduler_type, max_steps, warmup_ratio = "cosine", -1, 0.03
group_by_length, save_steps, logging_steps = True, 0, 25
max_seq_length, packing, device_map = 1024, False, {"": 0}

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# %%
# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:13<00:00,  6.96s/it]

# %%
# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.model_max_length = max_seq_length
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# %%
# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# %%
import os
os.environ["NCCL_P2P_DISABLE"] = "1"
os.environ["NCCL_IB_DISABLE"] = "1"

# %%
# Set training parameters

training_arguments = SFTConfig(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    max_length=max_seq_length,
    dataset_text_field="text",
    packing=packing,
)

# %%
# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=transformed_dataset,
    peft_config=peft_config,
    processing_class=tokenizer,
    args=training_arguments,
)
# Out:
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='409' max='65160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  409/65160 02:26 < 6:29:40, 2.77 it/s, Epoch 0.01/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.283400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.480100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.316700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.438900</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.150300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.347500</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>1.126600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.223000</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>1.013200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.146300</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>1.067300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.001400</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>1.005500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.937800</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.962000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.927000</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 trainer.train()
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/transformers/trainer.py:2240, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2238         hf_hub_utils.enable_progress_bars()
#    2239 else:
# -> 2240     return inner_training_loop(
#    2241         args=args,
#    2242         resume_from_checkpoint=resume_from_checkpoint,
#    2243         trial=trial,
#    2244         ignore_keys_for_eval=ignore_keys_for_eval,
#    2245     )
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/transformers/trainer.py:2588, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2583     _grad_norm = nn.utils.clip_grad_norm_(
#    2584         amp.master_params(self.optimizer),
#    2585         args.max_grad_norm,
#    2586     )
#    2587 else:
# -> 2588     _grad_norm = self.accelerator.clip_grad_norm_(
#    2589         model.parameters(),
#    2590         args.max_grad_norm,
#    2591     )
#    2593 if (
#    2594     is_accelerate_available()
#    2595     and self.accelerator.distributed_type == DistributedType.DEEPSPEED
#    2596 ):
#    2597     grad_norm = model.get_global_grad_norm()
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/accelerate/accelerator.py:2629, in Accelerator.clip_grad_norm_(self, parameters, max_norm, norm_type)
#    2627                 return model.clip_grad_norm_(max_norm, norm_type)
#    2628 self.unscale_gradients()
# -> 2629 return torch.nn.utils.clip_grad_norm_(parameters, max_norm, norm_type=norm_type)
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/torch/nn/utils/clip_grad.py:38, in _no_grad.<locals>._no_grad_wrapper(*args, **kwargs)
#      36 def _no_grad_wrapper(*args, **kwargs):
#      37     with torch.no_grad():
# ---> 38         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/torch/nn/utils/clip_grad.py:217, in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite, foreach)
#     214     parameters = [parameters]
#     215 else:
#     216     # prevent generators from being exhausted
# --> 217     parameters = list(parameters)
#     218 grads = [p.grad for p in parameters if p.grad is not None]
#     219 total_norm = _get_total_norm(grads, norm_type, error_if_nonfinite, foreach)
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/torch/nn/modules/module.py:2642, in Module.parameters(self, recurse)
#    2620 def parameters(self, recurse: bool = True) -> Iterator[Parameter]:
#    2621     r"""Return an iterator over module parameters.
#    2622
#    2623     This is typically passed to an optimizer.
#    (...)
#    2640
#    2641     """
# -> 2642     for _name, param in self.named_parameters(recurse=recurse):
#    2643         yield param
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/torch/nn/modules/module.py:2675, in Module.named_parameters(self, prefix, recurse, remove_duplicate)
#    2648 r"""Return an iterator over module parameters, yielding both the name of the parameter as well as the parameter itself.
#    2649
#    2650 Args:
#    (...)
#    2667
#    2668 """
#    2669 gen = self._named_members(
#    2670     lambda module: module._parameters.items(),
#    2671     prefix=prefix,
#    2672     recurse=recurse,
#    2673     remove_duplicate=remove_duplicate,
#    2674 )
# -> 2675 yield from gen
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/torch/nn/modules/module.py:2610, in Module._named_members(self, get_members_fn, prefix, recurse, remove_duplicate)
#    2604 memo = set()
#    2605 modules = (
#    2606     self.named_modules(prefix=prefix, remove_duplicate=remove_duplicate)
#    2607     if recurse
#    2608     else [(prefix, self)]
#    2609 )
# -> 2610 for module_prefix, module in modules:
#    2611     members = get_members_fn(module)
#    2612     for k, v in members:
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/torch/nn/modules/module.py:2832, in Module.named_modules(self, memo, prefix, remove_duplicate)
#    2830     continue
#    2831 submodule_prefix = prefix + ("." if prefix else "") + name
# -> 2832 yield from module.named_modules(
#    2833     memo, submodule_prefix, remove_duplicate
#    2834 )
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/torch/nn/modules/module.py:2832, in Module.named_modules(self, memo, prefix, remove_duplicate)
#    2830     continue
#    2831 submodule_prefix = prefix + ("." if prefix else "") + name
# -> 2832 yield from module.named_modules(
#    2833     memo, submodule_prefix, remove_duplicate
#    2834 )
#
#     [... skipping similar frames: Module.named_modules at line 2832 (5 times)]
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/torch/nn/modules/module.py:2832, in Module.named_modules(self, memo, prefix, remove_duplicate)
#    2830     continue
#    2831 submodule_prefix = prefix + ("." if prefix else "") + name
# -> 2832 yield from module.named_modules(
#    2833     memo, submodule_prefix, remove_duplicate
#    2834 )
#
# File ~/anaconda3/envs/llm_subject/lib/python3.10/site-packages/torch/nn/modules/module.py:2826, in Module.named_modules(self, memo, prefix, remove_duplicate)
#    2824 if self not in memo:
#    2825     if remove_duplicate:
# -> 2826         memo.add(self)
#    2827     yield prefix, self
#    2828     for name, module in self._modules.items():
#
# KeyboardInterrupt:

# %%
# Save trained model
trainer.model.save_pretrained(finetune_model)

# %%
# Reload and merge
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map=device_map,
)
model = PeftModel.from_pretrained(base_model, finetune_model)
model = model.merge_and_unload()

# Reload tokenizer to save it
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:03<00:00,  1.81s/it]

# %%
# save_path = "./llama-2-7b-chat-base.pt"

# %%
# base_model.save_pretrained(save_path)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model.save_pretrained("models/finetune_model.pt")
tokenizer.save_pretrained("models/tokenizer/")
# Out:
# ('models/tokenizer/tokenizer_config.json',
#  'models/tokenizer/special_tokens_map.json',
#  'models/tokenizer/tokenizer.json')

# %%
# Free VRAM
import gc
# del model, pipe, trainer
del trainer

gc.collect()
# Out:
# 6397

# %%
tokenizer = AutoTokenizer.from_pretrained("models/tokenizer/")
model = AutoModelForCausalLM.from_pretrained(
    "models/finetune_model.pt",
    torch_dtype="auto",
    device_map="auto"
)
# Out:
# Loading checkpoint shards: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it]
# We've detected an older driver with an RTX 4000 series GPU. These drivers have issues with P2P. This can affect the multi-gpu inference when using accelerate device_map.Please make sure to update your driver to the latest version which resolves this.

# %%
# Test the model with a sample question
val_dataset = load_dataset(dataset_name, split='validation')
val_dataset = val_dataset.select(range(100))
val_transformed_dataset = val_dataset.map(transform_conversation)
val_transformed_dataset = val_transformed_dataset.shuffle(seed=42)
val_transformed_dataset[2]
# Out:
# Map: 100%|██████████| 100/100 [00:00<00:00, 4640.79 examples/s]
# {'id': '5ad3e96b604f3c001a3ff68a',
#  'title': 'Normans',
#  'context': 'Some Normans joined Turkish forces to aid in the destruction of the Armenians vassal-states of Sassoun and Taron in far eastern Anatolia. Later, many took up service with the Armenian state further south in Cilicia and the Taurus Mountains. A Norman named Oursel led a force of "Franks" into the upper Euphrates valley in northern Syria. From 1073 to 1074, 8,000 of the 20,000 troops of the Armenian general Philaretus Brachamius were Normans—formerly of Oursel—led by Raimbaud. They even lent their ethnicity to the name of their castle: Afranji, meaning "Franks." The known trade between Amalfi and Antioch and between Bari and Tarsus may be related to the presence of Italo-Normans in those cities while Amalfi and Bari were under Norman rule in Italy.',
#  'question': 'Who did the Turks take up service with?',
#  'answers': {'text': [], 'answer_start': []},
#  'text': '<s>[INST] Context: Some Normans joined Turkish forces to aid in the destruction of the Armenians vassal-states of Sassoun and Taron in far eastern Anatolia. Later, many took up service with the Armenian state further south in Cilicia and the Taurus Mountains. A Norman named Oursel led a force of "Franks" into the upper Euphrates valley in northern Syria. From 1073 to 1074, 8,000 of the 20,000 troops of the Armenian general Philaretus Brachamius were Normans—formerly of Oursel—led by Raimbaud. They even lent their ethnicity to the name of their castle: Afranji, meaning "Franks." The known trade between Amalfi and Antioch and between Bari and Tarsus may be related to the presence of Italo-Normans in those cities while Amalfi and Bari were under Norman rule in Italy. Question: Who did the Turks take up service with? [/INST]  </s>'}

# %%
# Create a pipeline for question answering
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device_map="auto",
    torch_dtype=torch.float16
)

sample = transformed_dataset[16]

sample_context = sample['context']
sample_question = sample['question']
input_text = f"Context: {sample_context} Question: {sample_question}"

output = pipe(f"[INST] {input_text} [/INST]")
output_text = output[0]['generated_text']
print(output_text)
print(f"Expected answer: {sample['answers']['text'][0] if sample['answers']['text'] else ''}")
# Out:
# Device set to use cuda:0
# [INST] Context: Wood unsuitable for construction in its native form may be broken down mechanically (into fibers or chips) or chemically (into cellulose) and used as a raw material for other building materials, such as engineered wood, as well as chipboard, hardboard, and medium-density fiberboard (MDF). Such wood derivatives are widely used: wood fibers are an important component of most paper, and cellulose is used as a component of some synthetic materials. Wood derivatives can also be used for kinds of flooring, for example laminate flooring. Question: What material results from chemically breaking down wood? [/INST] cellulose
# Expected answer: cellulose

# %%
from tqdm import tqdm
pbar = tqdm(enumerate(val_transformed_dataset), total=len(val_transformed_dataset), desc="Generating answers")
answers = {}

for i, sample in pbar:
    sample_context = sample['context']
    sample_question = sample['question']
    input_text = f"Context: {sample_context} Question: {sample_question}"
    output = pipe(f"[INST] {input_text} [/INST]")
    output_text = output[0]['generated_text']
    output_text = output_text.split("[/INST]")[-1].strip()
    answers[sample['id']] = output_text
# Out:
# Generating answers: 100%|██████████| 100/100 [00:12<00:00,  7.93it/s]

# %%
import json
from collections import defaultdict

def convert_hf_squad2_to_json(hf_dataset, version="v2.0"):
    """
    Converts a Hugging Face SQuAD v2.0 dataset (or subset) to official SQuAD 2.0 JSON format.
    Args:
        hf_dataset: HuggingFace Dataset (e.g., dataset["train"] or a sampled subset)
        output_path: Path to save the JSON file
        version: SQuAD version string (default "v2.0")
    """
    def format_answers(answers):
        # Converts {'text': [...], 'answer_start': [...]} to list of dicts
        return [
            {"text": t, "answer_start": s}
            for t, s in zip(answers["text"], answers["answer_start"])
        ] if answers and "text" in answers and "answer_start" in answers else []

    data_dict = defaultdict(lambda: defaultdict(list))

    for ex in hf_dataset:
        print(ex['id'])
        title = ex.get("title", "No Title")
        context = ex["context"]
        qas_entry = {
            "id": ex["id"],
            "question": ex["question"],
            "is_impossible": ex.get("is_impossible", False),
            "answers": format_answers(ex["answers"])
        }
        if ex.get("is_impossible", False):
            plausible_answers = ex.get("plausible_answers")
            if plausible_answers:
                qas_entry["plausible_answers"] = format_answers(plausible_answers)
            else:
                qas_entry["plausible_answers"] = []
        data_dict[title][context].append(qas_entry)

    data = []
    for title, paras in data_dict.items():
        paragraphs = []
        for context, qas_list in paras.items():
            paragraphs.append({
                "context": context,
                "qas": qas_list
            })
        data.append({
            "title": title,
            "paragraphs": paragraphs
        })

    squad_json = {
        "version": version,
        "data": data
    }
    return squad_json

# %%
val_squad_form = convert_hf_squad2_to_json(val_dataset)
# Out:
# 56ddde6b9a695914005b9628
# 56ddde6b9a695914005b9629
# 56ddde6b9a695914005b962a
# 56ddde6b9a695914005b962b
# 56ddde6b9a695914005b962c
# 5ad39d53604f3c001a3fe8d1
# 5ad39d53604f3c001a3fe8d2
# 5ad39d53604f3c001a3fe8d3
# 5ad39d53604f3c001a3fe8d4
# 56dddf4066d3e219004dad5f
# 56dddf4066d3e219004dad60
# 56dddf4066d3e219004dad61
# 5ad3a266604f3c001a3fea27
# 5ad3a266604f3c001a3fea28
# 5ad3a266604f3c001a3fea29
# 5ad3a266604f3c001a3fea2a
# 5ad3a266604f3c001a3fea2b
# 56dde0379a695914005b9636
# 56dde0379a695914005b9637
# 5ad3ab70604f3c001a3feb89
# 5ad3ab70604f3c001a3feb8a
# 56dde0ba66d3e219004dad75
# 56dde0ba66d3e219004dad76
# 56dde0ba66d3e219004dad77
# 5ad3ad61604f3c001a3fec0d
# 5ad3ad61604f3c001a3fec0e
# 5ad3ad61604f3c001a3fec0f
# 5ad3ad61604f3c001a3fec10
# 56dde1d966d3e219004dad8d
# 5ad3ae14604f3c001a3fec39
# 5ad3ae14604f3c001a3fec3a
# 56dde27d9a695914005b9651
# 56dde27d9a695914005b9652
# 5ad3af11604f3c001a3fec63
# 5ad3af11604f3c001a3fec64
# 5ad3af11604f3c001a3fec65
# 56dde2fa66d3e219004dad9b
# 5ad3c626604f3c001a3ff011
# 5ad3c626604f3c001a3ff012
# 5ad3c626604f3c001a3ff013
# 56de0f6a4396321400ee257f
# 5ad3dbc6604f3c001a3ff3e9
# 5ad3dbc6604f3c001a3ff3ea
# 5ad3dbc6604f3c001a3ff3eb
# 5ad3dbc6604f3c001a3ff3ec
# 56de0ffd4396321400ee258d
# 56de0ffd4396321400ee258e
# 56de0ffd4396321400ee258f
# 5ad3de8b604f3c001a3ff467
# 5ad3de8b604f3c001a3ff468
# 5ad3de8b604f3c001a3ff469
# 5ad3de8b604f3c001a3ff46a
# 56de10b44396321400ee2593
# 56de10b44396321400ee2594
# 56de10b44396321400ee2595
# 5ad3e96b604f3c001a3ff689
# 5ad3e96b604f3c001a3ff68a
# 5ad3e96b604f3c001a3ff68b
# 5ad3e96b604f3c001a3ff68c
# 56de11154396321400ee25aa
# 5ad3ea79604f3c001a3ff6e9
# 5ad3ea79604f3c001a3ff6ea
# 5ad3ea79604f3c001a3ff6eb
# 56de148dcffd8e1900b4b5bc
# 56de148dcffd8e1900b4b5bd
# 56de148dcffd8e1900b4b5be
# 5ad3ed26604f3c001a3ff799
# 5ad3ed26604f3c001a3ff79a
# 5ad3ed26604f3c001a3ff79b
# 5ad3ed26604f3c001a3ff79c
# 56de15104396321400ee25b7
# 56de15104396321400ee25b8
# 56de15104396321400ee25b9
# 5ad3ee2d604f3c001a3ff7e1
# 5ad3ee2d604f3c001a3ff7e2
# 5ad3ee2d604f3c001a3ff7e3
# 56de1563cffd8e1900b4b5c2
# 56de1563cffd8e1900b4b5c3
# 56de1563cffd8e1900b4b5c4
# 5ad3f028604f3c001a3ff823
# 5ad3f028604f3c001a3ff824
# 5ad3f028604f3c001a3ff825
# 56de15dbcffd8e1900b4b5c8
# 56de15dbcffd8e1900b4b5c9
# 56de15dbcffd8e1900b4b5ca
# 56de15dbcffd8e1900b4b5cb
# 5ad3f187604f3c001a3ff86f
# 5ad3f187604f3c001a3ff870
# 5ad3f187604f3c001a3ff871
# 56de1645cffd8e1900b4b5d0
# 56de1645cffd8e1900b4b5d1
# 56de1645cffd8e1900b4b5d2
# 5ad3f350604f3c001a3ff8ef
# 5ad3f350604f3c001a3ff8f0
# 5ad3f350604f3c001a3ff8f1
# 56de16ca4396321400ee25c5
# 56de16ca4396321400ee25c6
# 56de16ca4396321400ee25c7
# 56de16ca4396321400ee25c8
# 5ad3f4b1604f3c001a3ff951

# %%
import json

with open("data.json", "w") as f:
    json.dump(val_squad_form, f)

with open("pred.json", "w") as f:
    json.dump(answers, f)
